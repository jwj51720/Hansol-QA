# %%
import pandas as pd

# %% [markdown]
# # 1. train.csv

# %%
train = pd.read_csv('data/train.csv')

# %% [markdown]
# ## 1-1. id
# - NULL 없음
# - TRAIN_000부터 TRAIN_643까지 644개의 고유한 값 -> data indexing을 위한 것일 뿐

# %%
print(len(train['id']))
print(train['id'].nunique())
# Out:
# 644
# 644

# %% [markdown]
# - 질문_1, 질문_2 : 샘플 별 동일한 내용으로 구성된 질문 2개
#
# ## 1-2. 질문_1
# - NULL 없음
# - '장판의 장점이 뭐야?'는 2개, 나머지는 1개 -> 643개의 unique 질문
#
# ## 1-3. 질문_2
# - NULL 없음
# - '오리지널징크의 장점은 무엇인가요?'는 2개, 나머지는 1개 -> 643개의 unique 질문
# ---
# - 하지만 질문_1과 질문_2이 동일한 내용이라고 보기는 어려움.
# - 존댓말 + 조금 더 구체적인 질문이긴 하나, '장판의 단점이 뭐야?' -> '장판의 장점과 단점에는 무엇이 있나요?' 이렇게 되는 경우가 있음.

# %%
display(train[train['질문_1'] == '장판의 장점이 뭐야?'])
print(len(train['질문_1'].value_counts()))

display(train[train['질문_2'] == '오리지널징크의 장점은 무엇인가요?'])
print(len(train['질문_2'].value_counts()))
# Out:
#             id         질문_1                       질문_2 category  \
# 101  TRAIN_101  장판의 장점이 뭐야?  장판을 선택하는 이유에는 어떤 것이 있을까요?      마감재
# 143  TRAIN_143  장판의 장점이 뭐야?     장판을 사용하는 것의 장점은 무엇인가요?      마감재
#
#                                                   답변_1  \
# 101  장판은 단가와 시공비가 저렴하고 보행감이 좋으며 높은 열전도율로 난방효과가 좋고 층...
# 143  장판은 보행감이 좋고 디자인이 다양하며 방수성이 좋고 가격이 저렴하다는 장점이 있습니다.
#
#                                                   답변_2  \
# 101  장판은 단가와 시공비가 저렴하여 비용 효율적이며 보행감이 좋아 편안한 걷기가 가능합...
# 143  장판의 장점은 다양한 디자인과 보행감이 좋은 것 외에도 방수성이 뛰어나고 비교적 저...
#
#                                                   답변_3  \
# 101  장판은 저렴한 단가와 시공비, 특히 보행감이 우수하며 높은 열전도율로 난방효과가 뛰...
# 143  장판은 보행감이 우수하여 안전하고, 다양한 디자인으로 공간에 미감을 더해주는 장점이...
#
#                                                   답변_4  \
# 101  장판의 장점은 단가와 시공비가 저렴하고 보행감이 좋으며 높은 열전도율로 난방효과가 ...
# 143  장판의 장점은 다양한 디자인과 보행감의 편의성, 높은 방수성과 비교적 낮은 비용으로...
#
#                                                   답변_5
# 101  장판은 층간 소음 방지에 좋고, 보행감이 우수하여 안전하고 편안합니다. 또한 열전도...
# 143  장판은 바닥재료로 사용할 때 보행감이 좋고, 다양한 디자인과 색상을 선택할 수 있어...
# 643
#             id             질문_1                질문_2 category  \
# 65   TRAIN_065  오리지널징크의 장점이 뭐야?  오리지널징크의 장점은 무엇인가요?      마감재
# 167  TRAIN_167  오리지널징크의 단점이 뭐야?  오리지널징크의 장점은 무엇인가요?      마감재
#
#                                                   답변_1  \
# 65   오리지널징크는 다른 징크에 비해 수명이 길고 다양한 패턴과 디자인이 가능하며 친환경...
# 167                 오리지널징크는 다른 징크에 비해 가격이 높은 것이 단점입니다.
#
#                                                   답변_2  \
# 65   오리지널징크의 장점은 다른 징크에 비해 수명이 길며 다양한 패턴과 디자인이 가능하다...
# 167  오리지널징크의 단점은 다른 징크에 비해 가격이 상대적으로 높다는 것입니다. 또한, ...
#
#                                                   답변_3  \
# 65   오리지널징크는 고온, 저온, 습한 환경에서도 안정적이며, 내식성이 매우 뛰어나기 때...
# 167  오리지널 징크의 단점으로는 비교적 다른 징크에 비해 높은 가격이 있습니다. 그러나 ...
#
#                                                   답변_4  \
# 65   오리지널징크의 장점은 다양한 패턴과 디자인을 적용할 수 있다는 것입니다. 또한 친환...
# 167  오리지널 징크의 단점은 다른 징크에 비해 비교적 높은 가격이라는 점입니다. 이러한 ...
#
#                                                   답변_5
# 65   오리지널징크는 다른 징크에 비해 수명이 길고 다양한 패턴과 디자인이 가능하며 친환경...
# 167  오리지널징크의 단점 중 하나는 가격이 다른 징크에 비해 비교적 높다는 점입니다. 하...
# 643

# %%
display(train[train['질문_1'].str.contains('장판')])
display(train[train['질문_1'].str.contains('오리지널징크')])
# Out:
#             id                              질문_1  \
# 71   TRAIN_071                  장판이 남으면 어떻게 처리해?
# 101  TRAIN_101                       장판의 장점이 뭐야?
# 143  TRAIN_143                       장판의 장점이 뭐야?
# 166  TRAIN_166  아이가 있는 집은 두꺼운 장판과 마루 중 어느 것이 좋아?
# 296  TRAIN_296                  비닐장판의 기대수명은 얼마야?
# 313  TRAIN_313                       장판의 단점이 뭐야?
# 395  TRAIN_395           누수공사 업체에서 장판 마감 작업도 해줘?
# 429  TRAIN_429                  장판 시공 시간은 어떻게 돼?
# 451  TRAIN_451                   장판 견적은 어떻게 계산해?
#
#                                                질문_2 category  \
# 71                        장판이 남을 경우에는 어떻게 처리해야 하나요?      마감재
# 101                       장판을 선택하는 이유에는 어떤 것이 있을까요?      마감재
# 143                          장판을 사용하는 것의 장점은 무엇인가요?      마감재
# 166  아이가 있는 집에서는 두꺼운 장판과 마루 중 어떤 것을 선택하는 게 더 안전한가요?      마감재
# 296                          비닐장판의 기대 수명은 얼마 정도인가요?      마감재
# 313                           장판의 장점과 단점에는 무엇이 있나요?      마감재
# 395             누수공사 업체에서 장판 마감 작업을 제공하는 것이 일반적인가요?       시공
# 429                         장판 시공하는 데 얼마나 시간이 걸리나요?       시공
# 451                    장판 견적을 계산하는 데 중요한 요소는 무엇인가요?       시공
#
#                                                   답변_1  \
# 71   장판 처리방법은 구청, 주민센터에서 생활폐기물 스티커를 구매 후 배출해야 합니다. ...
# 101  장판은 단가와 시공비가 저렴하고 보행감이 좋으며 높은 열전도율로 난방효과가 좋고 층...
# 143  장판은 보행감이 좋고 디자인이 다양하며 방수성이 좋고 가격이 저렴하다는 장점이 있습니다.
# 166  아이가 있는 집에는 두꺼운 장판을 추천드립니다. 아이가 있는 경우 층간 소음이 발생...
# 296                                비닐장판의 기대수명은 10년입니다.
# 313                      장판은 찍힘, 눌림 등에 취약하다는 단점이 있습니다.
# 395     일반적으로 누수공사 업체에서는 누수공사만 진행하고 장판 마감 작업은 하지 않습니다.
# 429  일반적으로 장판 시공 시간은 2~3시간으로 알려져 있습니다. 하지만 시공현장의 상태...
# 451  장판 견적은 일반적으로 시공현장의 상태, 장판, 인건비를 포함해서 계산해야 합니다....
#
#                                                   답변_2  \
# 71   장판 처리방법은 생활폐기물 스티커를 구매한 뒤, 지역의 구청 또는 주민센터에서 배출...
# 101  장판은 단가와 시공비가 저렴하여 비용 효율적이며 보행감이 좋아 편안한 걷기가 가능합...
# 143  장판의 장점은 다양한 디자인과 보행감이 좋은 것 외에도 방수성이 뛰어나고 비교적 저...
# 166  아이가 있는 집에는 두꺼운 장판을 사용하는 것이 좋습니다. 아이가 있는 경우 층간 ...
# 296  비닐장판의 기대수명은 일반적으로 10년 정도입니다. 다만 사용환경, 노출정도, 방식...
# 313  장판의 단점은 찍힘, 눌림 등에 취약하다는 것입니다. 또한, 물이나 습기에 노출될 ...
# 395  일반적으로 누수공사 업체에서는 주로 누수 공사에 특화되어 있으므로, 장판 마감 작업...
# 429  일반적으로 장판 시공 시간은 2~3시간으로 알려져 있습니다. 그러나 시공면적 및 시...
# 451  장판 견적은 일반적으로 시공현장의 상태, 장판 자체의 소재와 크기, 그리고 인건비를...
#
#                                                   답변_3  \
# 71   장판이 남을 경우에는 구청이나 주민센터에서 생활폐기물 스티커를 구매하여 해당 기관이...
# 101  장판은 저렴한 단가와 시공비, 특히 보행감이 우수하며 높은 열전도율로 난방효과가 뛰...
# 143  장판은 보행감이 우수하여 안전하고, 다양한 디자인으로 공간에 미감을 더해주는 장점이...
# 166  아이가 있는 집에는 두꺼운 장판을 사용하는 것이 좋습니다. 두꺼운 장판은 아이가 떨...
# 296  비닐장판의 일반적인 기대수명은 10년 정도입니다. 그러나 품질이나 사용 환경에 따라...
# 313  장판의 단점 중 하나는 찍힘과 눌림에 취약하다는 점입니다. 이러한 현상은 사용 빈도...
# 395  누수공사 업체에서는 일반적으로 누수공사만 진행하며, 장판 마감 작업은 보통 하지 않...
# 429  일반적으로 장판 시공 시간은 2~3시간이 소요됩니다. 그러나 시공현장의 상태나 시공...
# 451  장판 견적은 일반적으로 시공현장의 상태, 장판 자재 및 배치, 인건비 등을 종합적으...
#
#                                                   답변_4  \
# 71   장판 처리방법은 구청이나 주민센터에서 생활폐기물 스티커를 구매한 후 배출해야 합니다...
# 101  장판의 장점은 단가와 시공비가 저렴하고 보행감이 좋으며 높은 열전도율로 난방효과가 ...
# 143  장판의 장점은 다양한 디자인과 보행감의 편의성, 높은 방수성과 비교적 낮은 비용으로...
# 166  아이가 있는 집에는 두꺼운 장판을 사용하는 것이 좋습니다. 두꺼운 장판은 층간 소음...
# 296  비닐장판의 일반적인 기대수명은 10년입니다. 그러나 사용 환경, 유지보수 여부 및 ...
# 313  장판의 단점은 찍힘과 눌림에 취약하다는 것입니다. 또한 장판은 습기에 민감하여 변형...
# 395  보통 누수공사 업체는 주로 누수공사에 특화되어 있어서 장판 마감 작업을 하지 않습니...
# 429  일반적으로 장판 시공 시간은 2~3시간으로 알려져 있습니다. 시공면적과 시공자의 숙...
# 451  장판 견적은 시공현장의 상태, 장판 소재, 면적 및 재료비, 그리고 인건비 등을 종...
#
#                                                   답변_5
# 71   장판 처리방법에 대해 알려드리겠습니다. 장판은 생활폐기물 스티커를 구매한 후 구청 ...
# 101  장판은 층간 소음 방지에 좋고, 보행감이 우수하여 안전하고 편안합니다. 또한 열전도...
# 143  장판은 바닥재료로 사용할 때 보행감이 좋고, 다양한 디자인과 색상을 선택할 수 있어...
# 166  아이가 있는 집에는 두꺼운 장판을 사용하는 것이 좋습니다. 아이가 있는 공간은 층간...
# 296  비닐장판은 일반적으로 10년 정도의 수명을 가지고 있습니다. 그러나 사용 환경, 방...
# 313  장판은 찍힘, 눌림 등에 취약하다는 단점이 있을 뿐만 아니라 습기에 노출되면 변형될...
# 395  누수공사 업체는 주로 누수 공사에 특화되어 있기 때문에 장판 마감 작업은 보통 하지...
# 429  일반적으로 장판 시공 시간은 2~3시간으로 알려져 있지만, 시공하는 장판의 종류, ...
# 451  장판 견적은 일반적으로 시공현장의 상태, 장판 자재 및 인건비를 포함하여 계산해야 ...
#             id             질문_1                질문_2 category  \
# 65   TRAIN_065  오리지널징크의 장점이 뭐야?  오리지널징크의 장점은 무엇인가요?      마감재
# 105  TRAIN_105      오리지널징크가 뭐야?  오리지널징크는 무엇을 의미하나요?      마감재
# 167  TRAIN_167  오리지널징크의 단점이 뭐야?  오리지널징크의 장점은 무엇인가요?      마감재
#
#                                                   답변_1  \
# 65   오리지널징크는 다른 징크에 비해 수명이 길고 다양한 패턴과 디자인이 가능하며 친환경...
# 105  오리지널 징크는 순도 99.995%의 아연과 소량의 티타늄과 구리가 첨가된 합금 판...
# 167                 오리지널징크는 다른 징크에 비해 가격이 높은 것이 단점입니다.
#
#                                                   답변_2  \
# 65   오리지널징크의 장점은 다른 징크에 비해 수명이 길며 다양한 패턴과 디자인이 가능하다...
# 105  오리지널 징크란 순도 99.995%의 아연과 소량의 티타늄과 구리가 첨가된 합금 판...
# 167  오리지널징크의 단점은 다른 징크에 비해 가격이 상대적으로 높다는 것입니다. 또한, ...
#
#                                                   답변_3  \
# 65   오리지널징크는 고온, 저온, 습한 환경에서도 안정적이며, 내식성이 매우 뛰어나기 때...
# 105  오리지널 징크는 순도 99.995%의 아연과 소량의 티타늄과 구리가 첨가된 합금 판...
# 167  오리지널 징크의 단점으로는 비교적 다른 징크에 비해 높은 가격이 있습니다. 그러나 ...
#
#                                                   답변_4  \
# 65   오리지널징크의 장점은 다양한 패턴과 디자인을 적용할 수 있다는 것입니다. 또한 친환...
# 105  오리지널 징크는 순도 99.995%의 아연과 소량의 티타늄과 구리가 첨가된 합금 판...
# 167  오리지널 징크의 단점은 다른 징크에 비해 비교적 높은 가격이라는 점입니다. 이러한 ...
#
#                                                   답변_5
# 65   오리지널징크는 다른 징크에 비해 수명이 길고 다양한 패턴과 디자인이 가능하며 친환경...
# 105  오리지널 징크는 순도 99.995%의 아연과 소량의 티타늄과 구리가 첨가된 합금 판...
# 167  오리지널징크의 단점 중 하나는 가격이 다른 징크에 비해 비교적 높다는 점입니다. 하...
