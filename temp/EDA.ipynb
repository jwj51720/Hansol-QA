# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# # 1. train.csv

# %%
train = pd.read_csv('data/train.csv')

# %% [markdown]
# ## 1-1. id
# - NULL 없음
# - TRAIN_000부터 TRAIN_643까지 644개의 고유한 값 -> data indexing을 위한 것일 뿐

# %%
print(len(train['id']))
print(train['id'].nunique())
# Out:
# 644
# 644

# %% [markdown]
# - 질문_1, 질문_2 : 샘플 별 동일한 내용으로 구성된 질문 2개
#
# ## 1-2. 질문_1
# - NULL 없음
# - '장판의 장점이 뭐야?'는 2개, 나머지는 1개 -> 643개의 unique 질문
#
# ## 1-3. 질문_2
# - NULL 없음
# - '오리지널징크의 장점은 무엇인가요?'는 2개, 나머지는 1개 -> 643개의 unique 질문
# ---
# - 하지만 질문_1과 질문_2이 동일한 내용이라고 보기는 어려움.
# - 존댓말 + 조금 더 구체적인 질문이긴 하나, '장판의 단점이 뭐야?' -> '장판의 장점과 단점에는 무엇이 있나요?' 이렇게 되는 경우가 있음.
#     - 하지만 이 경우에 5개의 답변은 모두 '단점'만 설명하고 있음. 질문_1로 5개 답변을 생성하고, 질문_2는 질문_1의 유사 답변으로 자동 생성하게 한 것 같다는 생각이 든다. 사실상 질문_1이 제대로 된 질문일 수도 있을 것 같다.
#     - 질문1 -> GPT로 답변 5개 생성 / 질문_1 -> GPT로 비슷한 질문 1개 생성... 이런 느낌인 것 같음.
# - 다른 예시, 이때에도 5개 답변이 색상을 얘기하는 게 아니라 요소를 얘기함.
#     - 질문1: '인테리어에서 유럽의 전통적인 스타일을 살리려면 어떤 요소를 고려해야 하나요?'
#     - 질문2: '유럽의 전통적인 스타일을 살리기 위해 어떤 색상을 활용해야 할까요?'
# ---
# - 안 물어본 것도 답변하는 경우가 있음
#     - 벽에 뚫린 구멍이 이상해 -> 벽이나 천장에 잘못 뚫린 구멍을 "타공하자"라고 합니다. **_타공하자가 발생하는 원인과 그에 대한 책임 소재, 그리고 해결방법에 대해 설명드리겠습니다._** 1. 부실 시공 - 원인: 적절하지 않은 도구로 작업하거나 타공 부위의 크기를 정확히 측정하지 않고 작업하면 타공불량이 발생할 수 있습니다. - 책임 소재: 시공자 - 해결 방법: 타공 부위의 크기를 정확히 측정하고 올바른 도구를 사용하여 재작업해야 합니다.
# - pattern = r'[^a-zA-Z가-힣()\d.,?!\s\-`]'에서 모두 커버가 됨.
#     - 도막방수공사가 뭐야?\` -> 맨 뒤에 `가 붙어 있음.

# %%
display(train[train['질문_1'] == '장판의 장점이 뭐야?'])
print(len(train['질문_1'].value_counts()))

display(train[train['질문_2'] == '오리지널징크의 장점은 무엇인가요?'])
print(len(train['질문_2'].value_counts()))
# Out:
#             id         질문_1                       질문_2 category  \
# 101  TRAIN_101  장판의 장점이 뭐야?  장판을 선택하는 이유에는 어떤 것이 있을까요?      마감재
# 143  TRAIN_143  장판의 장점이 뭐야?     장판을 사용하는 것의 장점은 무엇인가요?      마감재
#
#                                                                      답변_1  \
# 101  장판은 단가와 시공비가 저렴하고 보행감이 좋으며 높은 열전도율로 난방효과가 좋고 층간 소음 방지에 좋다는 장점이 있습니다.
# 143                     장판은 보행감이 좋고 디자인이 다양하며 방수성이 좋고 가격이 저렴하다는 장점이 있습니다.
#
#                                                                                                                                                                                                         답변_2  \
# 101                                                 장판은 단가와 시공비가 저렴하여 비용 효율적이며 보행감이 좋아 편안한 걷기가 가능합니다. 또한 높은 열전도율로 인해 난방 효과가 좋고, 층간 소음 방지에도 탁월한 효과를 발휘합니다. 이러한 장점으로 인해 많은 사람들에게 선호되며, 실용적이고 효율적인 바닥재료로 선택됩니다.
# 143  장판의 장점은 다양한 디자인과 보행감이 좋은 것 외에도 방수성이 뛰어나고 비교적 저렴한 가격으로 구할 수 있다는 점입니다. 디자인의 다양성은 공간에 맞게 선택할 수 있는 유연성을 제공하며, 방수성은 바닥이나 벽면의 보호에 도움이 됩니다. 또한, 상대적으로 저렴한 가격으로 구할 수 있어 예산 내에서도 다양한 디자인과 재질을 선택할 수 있는 장점이 있습니다.
#
#                                                                                                                                      답변_3  \
# 101  장판은 저렴한 단가와 시공비, 특히 보행감이 우수하며 높은 열전도율로 난방효과가 뛰어나고 층간 소음을 효과적으로 방지할 수 있는 장점이 있습니다. 또한 표면의 디자인 및 색상 다양성으로 인해 인테리어와 어우러지는 멋진 외관을 자랑합니다.
# 143                   장판은 보행감이 우수하여 안전하고, 다양한 디자인으로 공간에 미감을 더해주는 장점이 있습니다. 또한 방수성이 뛰어나서 관리와 청소가 편리하며, 비교적 저렴한 가격대로 구입할 수 있는 것도 장점으로 꼽힙니다.
#
#                                                                                                                     답변_4  \
# 101         장판의 장점은 단가와 시공비가 저렴하고 보행감이 좋으며 높은 열전도율로 난방효과가 좋고 층간 소음 방지에 좋다는 점이 있습니다. 또한 편리한 시공과 다양한 디자인으로 인해 인기를 끌고 있습니다.
# 143  장판의 장점은 다양한 디자인과 보행감의 편의성, 높은 방수성과 비교적 낮은 비용으로 구할 수 있다는 점입니다. 또한, 다양한 재질과 색상, 패턴으로 공간의 분위기를 풍부하게 표현할 수 있어 인기가 많습니다.
#
#                                                                                                                                   답변_5
# 101                                       장판은 층간 소음 방지에 좋고, 보행감이 우수하여 안전하고 편안합니다. 또한 열전도율이 높아 난방효과도 뛰어나며, 단가와 시공비가 저렴하여 경제적인 장점이 있습니다.
# 143  장판은 바닥재료로 사용할 때 보행감이 좋고, 다양한 디자인과 색상을 선택할 수 있어 인테리어에 다양한 옵션을 제공합니다. 또한 방수성이 우수하고 비교적 저렴한 가격대를 형성하고 있어 다양한 공간에 활용하기에 매우 유용한 재료입니다.
# 643
#             id             질문_1                질문_2 category  \
# 65   TRAIN_065  오리지널징크의 장점이 뭐야?  오리지널징크의 장점은 무엇인가요?      마감재
# 167  TRAIN_167  오리지널징크의 단점이 뭐야?  오리지널징크의 장점은 무엇인가요?      마감재
#
#                                                                                            답변_1  \
# 65   오리지널징크는 다른 징크에 비해 수명이 길고 다양한 패턴과 디자인이 가능하며 친환경적이고 금속 부식에 대한 내식성이 뛰어나 유지보수가 용이하다는 장점이 있습니다.
# 167                                                          오리지널징크는 다른 징크에 비해 가격이 높은 것이 단점입니다.
#
#                                                                                                                                                                답변_2  \
# 65         오리지널징크의 장점은 다른 징크에 비해 수명이 길며 다양한 패턴과 디자인이 가능하다는 점입니다. 또한, 친환경적이고 금속 부식에 대한 내식성이 뛰어나 유지보수가 용이하다는 특징이 있습니다. 이러한 이점들로 인해 오리지널징크는 건물 외벽 및 지붕재로 널리 사용되고 있습니다.
# 167  오리지널징크의 단점은 다른 징크에 비해 가격이 상대적으로 높다는 것입니다. 또한, 오리지널징크는 처음에는 회색 빛을 띠고 있지만 시간이 지남에 따라 갈색 또는 검은색으로 변할 수도 있습니다. 이러한 색 변화는 몇 년 이내에 일어나지만 일부 사람들은 이러한 변화를 선호할 수 있습니다.
#
#                                                                                                                               답변_3  \
# 65   오리지널징크는 고온, 저온, 습한 환경에서도 안정적이며, 내식성이 매우 뛰어나기 때문에 장기간 사용이 가능합니다. 또한 오리지널징크는 다양한 패턴과 디자인이 가능하고, 친환경적인 소재로 유지보수가 용이하다는 장점이 있습니다.
# 167                       오리지널 징크의 단점으로는 비교적 다른 징크에 비해 높은 가격이 있습니다. 그러나 오리지널 징크는 품질과 내구성 측면에서 다른 저렴한 대체품들보다 우수한 성능을 보여주는 경우가 많습니다.
#
#                                                                                                                                                      답변_4  \
# 65                                                     오리지널징크의 장점은 다양한 패턴과 디자인을 적용할 수 있다는 것입니다. 또한 친환경적이고 높은 내식성이 있어 수명이 다른 징크에 비해 길며 유지보수가 쉽다는 점이 있습니다.
# 167  오리지널 징크의 단점은 다른 징크에 비해 비교적 높은 가격이라는 점입니다. 이러한 가격 차이는 소비자들이 징크를 선택할 때 고려해야 하는 중요한 요소 중 하나입니다. 나아가 오리지널 징크는 상대적으로 부식방지 능력이 떨어지는 등 일부 다른 단점도 있을 수 있습니다.
#
#                                                                                                                                                                     답변_5
# 65                   오리지널징크는 다른 징크에 비해 수명이 길고 다양한 패턴과 디자인이 가능하며 친환경적이고 금속 부식에 대한 내식성이 뛰어나 유지보수가 쉽다는 장점이 있습니다. 또한 오리지널징크는 가벼우면서도 매우 견고하며 낮은 유지보수 비용과 높은 재활용 가능성을 갖고 있습니다.
# 167  오리지널징크의 단점 중 하나는 가격이 다른 징크에 비해 비교적 높다는 점입니다. 하지만 이러한 추가비용이 지불하는 가치를 제공한다고도 할 수 있습니다. 추가적인 비용을 투자하는 대신 높은 품질과 오랜 수명을 기대할 수 있기 때문에 오리지널징크를 선택하는 것이 실질적인 이득이 될 수 있습니다.
# 643

# %%
display(train[train['id'] == 'TRAIN_313'])
# Out:
#             id         질문_1                   질문_2 category  \
# 313  TRAIN_313  장판의 단점이 뭐야?  장판의 장점과 단점에는 무엇이 있나요?      마감재
#
#                               답변_1  \
# 313  장판은 찍힘, 눌림 등에 취약하다는 단점이 있습니다.
#
#                                                                                답변_2  \
# 313  장판의 단점은 찍힘, 눌림 등에 취약하다는 것입니다. 또한, 물이나 습기에 노출될 경우 변형되거나 파손될 수 있는 점 또한 고려해야 합니다.
#
#                                                                                                                                 답변_3  \
# 313  장판의 단점 중 하나는 찍힘과 눌림에 취약하다는 점입니다. 이러한 현상은 사용 빈도와 방식에 따라 발생할 수 있으며, 적절한 관리와 보수가 필요합니다. 또한 장판의 특성을 고려하여 가구나 무거운 물체를 옮길 때 조심해야 합니다.
#
#                                                                     답변_4  \
# 313  장판의 단점은 찍힘과 눌림에 취약하다는 것입니다. 또한 장판은 습기에 민감하여 변형되기 쉽다는 점도 단점으로 지적됩니다.
#
#                                                                                                                        답변_5
# 313  장판은 찍힘, 눌림 등에 취약하다는 단점이 있을 뿐만 아니라 습기에 노출되면 변형될 수 있는 성질을 가지고 있습니다. 따라서 습기 관리에 더욱 신경을 써야 하며, 마찰이나 압력에 노출되지 않도록 주의해야 합니다.

# %%
display(train[train['질문_1'].str.contains('인테리어에서 유럽의 전통적인 스타일을 살리려면 어떤 요소를 고려해야 하나요?')])
# Out:
#             id                                        질문_1  \
# 536  TRAIN_536  인테리어에서 유럽의 전통적인 스타일을 살리려면 어떤 요소를 고려해야 하나요?
#
#                                       질문_2 category  \
# 536  유럽의 전통적인 스타일을 살리기 위해 어떤 색상을 활용해야 할까요?     인테리어
#
#                                                                                              답변_1  \
# 536  유럽의 전통적인 스타일을 살리기 위해서는 고급스러운 가구, 화려한 조명, 세련된 패턴의 텍스처 등을 활용하여 전통적이면서도 우아하고 고요한 분위기를 조성해야 합니다.
#
#                                                                                                                                                                                                                                                                                                                                   답변_2  \
# 536  유럽의 전통적인 스타일을 살리기 위해서는 다음과 같은 요소를 고려해야 합니다. 먼저, 고급스러운 가구와 화려한 조명은 필수적인 부분이며, 세련된 패턴과 텍스처를 통해 전통적이면서도 우아하고 고요한 분위기를 조성하는 것이 중요합니다. 또한, 유럽의 전통 스타일을 반영하기 위해서는 고대의 유물, 앤틱 가구 및 오리지널 아트워크를 포함하는 것이 좋습니다. 또한, 대형 창문, 고고한 천장 및 벽지, 프레스티지한 마감재를 포함하여 부엌, 화장실 및 다른 주거 공간을 장식하는 것이 중요합니다. 마지막으로, 전통적 색상 팔레트를 사용하여 유럽 전통 스타일을 강조하는 것이 좋습니다.
#
#                                                                                                                                                                                                              답변_3  \
# 536  유럽의 전통적인 스타일을 살리기 위해서는 고급스러운 가구, 화려한 조명, 세련된 패턴의 텍스처 등이 중요합니다. 또한, 유럽 전통 건축물에서 영감을 받은 장식물이나 벽지, 후레스코 등을 사용하여 분위기를 조성하는 것이 좋습니다. 그리고 대리석, 우아한 나무재료 혹은 고급 질의 가죽 소재를 활용하여 인테리어를 디자인하는 것이 스타일을 살리는 데 도움이 될 것입니다.
#
#                                                                                                                                                                                                                                                      답변_4  \
# 536  유럽의 전통적인 스타일을 살리려면 몇 가지 주요 요소를 고려해야 합니다. 고급스럽고 우아한 분위기를 조성하기 위해 안티크 가구, 화려한 조명, 그림과 조각품 등 전통적이면서도 아름다운 소품을 활용하는 것이 중요합니다. 또한, 고급스러운 질감과 패턴의 텍스처를 활용하여 전통적이면서도 우아하고 고요한 분위기를 조성하는 것이 중요합니다. 생동감 있는 포스터나 타일, 그림과 드레이퍼리 역시 전통적인 유럽 스타일을 강조하는 데 도움이 됩니다.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         답변_5
# 536  유럽의 전통적인 스타일을 살리기 위해서는 다음과 같은 요소를 고려해야 합니다.  1. **고급스러운 가구**: 안티크 가구나 목공예품, 클래식한 디자인의 가구를 선택하여 전통적인 유럽 스타일을 표현할 수 있습니다.  2. **화려한 조명**: 크리스털 샹들리에나 고요한 색감의 조명을 활용하여 고급스러우면서도 전통적인 분위기를 연출할 수 있습니다.  3. **세련된 패턴의 텍스처**: 브로케이드, 플로랄, 체크무늬 등의 텍스처를 벽지, 커튼, 쿠션 등의 소품에 활용하여 전통적인 유럽 스타일을 강조할 수 있습니다.  4. **고풍스러운 색감**: 옅은 크림, 베이지, 고동색, 버건디 같은 색감을 활용하여 전통적이면서 우아하고 고요한 분위기를 조성할 수 있습니다.  5. **클래식한 작품 및 소품**: 골드나 황동의 장식품, 골드 프레임의 그림, 여러 가지 조각품 등을 활용하여 전통적이면서도 고급스러운 분위기를 연출할 수 있습니다.  이러한 요소들을 조화롭게 결합하여 유럽의 전통적인 스타일을 인테리어에 살릴 수 있습니다.

# %%
pattern = r'[^a-zA-Z가-힣()\d.,?!\s\-]'
mask = train[['질문_1', '질문_2']].apply(lambda x: x.str.contains(pattern)).any(axis=1)
print(len(train[mask]))
train[mask]
# Out:
# 1
#             id          질문_1                   질문_2 category  \
# 444  TRAIN_444  도막방수공사가 뭐야?`  도막방수공사는 무엇을 하는 작업인가요?       시공
#
#                                                                                                  답변_1  \
# 444  도막방수는 방수용으로 제조된 우레탄 고무계, 아크릴 고무계, 고무 아스팔트계 등의 액상형의 재료를 바탕에 발라 방수층을 형성하는 공법으로 액체방수를 하고 2차로 시공합니다.
#
#                                                                                                                                                                                                   답변_2  \
# 444  도막방수는 건물의 지붕, 벽, 바닥과 같은 부분에 방수용으로 제조된 우레탄 고무계, 아크릴 고무계, 고무 아스팔트계 등의 액상형 재료를 바탕에 발라 방수층을 형성하는 작업입니다. 이를 통해 액체 방수를 하고 건물을 보다 견고하게 보호할 수 있게 됩니다. 이렇게 도막방수를 시공함으로써 건물의 내부가 물에 절대로 노출되지 않고 유지될 수 있습니다.
#
#                                                                                                                                                                                                                                         답변_3  \
# 444  도막방수는 건물의 지붕, 외벽 또는 바닥과 같이 수분이 침투할 우려가 있는 부분에 방수용으로 제조된 우레탄 고무계, 아크릴 고무계, 고무 아스팔트계 등의 액상형 재료를 발라 방수층을 형성하는 공법을 말합니다. 이를 통해 액체방수를 하고 2차로 시공하여 건물에 수분 침투를 차단하고 내구성을 향상시키는 역할을 합니다. 도막방수는 건물의 수명을 연장시키고 내부를 보호함으로써 건물의 안전성을 높이는 중요한 작업입니다.
#
#                                                                                                                                                                                                            답변_4  \
# 444  도막방수는 건물의 지붕, 바닥 또는 기타 표면을 방수할 때 사용하는 방수공법입니다. 이 방법은 방수용으로 제조된 우레탄 고무계, 아크릴 고무계, 고무 아스팔트계와 같은 액상형의 재료를 표면에 발라 방수층을 형성하는 것으로, 액체방수를 하고 2차로 시공하는 방식으로 진행됩니다. 이를 통해 건물 내부가 누수되거나 수분에 노출됨으로 인한 손상을 방지할 수 있습니다.
#
#                                                                                                                                                         답변_5
# 444  도막방수는 건물의 외부나 내부에 방수용으로 제조된 우레탄 고무계, 아크릴 고무계, 고무 아스팔트계 등과 같은 액상형 재료를 바탕에 발라 방수층을 형성하는 공법을 말합니다. 이 방법은 액체방수를 하고 2차로 시공하여 건물의 수명을 연장하고 수분으로 인한 파손을 방지합니다.

# %% [markdown]
# # category
# - NULL 없음
# - '마감재', '인테리어', '시공', '마감하자', '건축구조', '기타', '타 마감하자'
# - 질문의 카테고리니까, 644 * 2개 만큼의 데이터가 존재하는 셈
#     - 질문을 보고 카테고리를 우선 분류하는 모델을 사용해보면 어떨까? -> 이후 RAG 사용하여 해당 카테고리만 읽으면 조금 더 정확해질 수도?
#     - 어차피 그런 분류 모델이라면 답변도 데이터로 사용해볼 수 있겠다.

# %%
train['category'].value_counts()
# Out:
# 마감재       272
# 인테리어      123
# 시공        111
# 마감하자       60
# 건축구조       31
# 기타         27
# 타 마감하자     20
# Name: category, dtype: int64

# %% [markdown]
# # 답변_N
# - NULL 없음
# - 답변1 -> 답변2 -> ... 순서대로 답변 내용이 추가되는 느낌. 비슷하거나 동일한 말이 반복되는 경우가 있음
# - 답변의 길이는 답변_1이 평균 95개 문자, 답변_2부터 답변_5까지는 195개 문자. 답변_1이 눈에 띄게 짧고, 나머지는 거의 비슷한 길이를 가짐.
# - 답변에 오타가 존재할 수 있음
#     - 노출콘크리트는 모던하며 다양한 인테리어 효ㅕ과와 공간의 확장감을 주고 별도의 마감재가 필요없으며 표면의 강도가 높다는 장점이 있습니다.
# - 확실히 GPT로 답변 생성했다는 것이 느껴지는 부분
#     - \## 수정된 답변 발포우레탄폼은 폴리우레탄 수지를 발포시켜 고화된 스폰지 모양의 외장재를 의미합니다. 주로 건물의 단열재나 수납 공간 등을 채우는 데 사용되며, 경량이면서도 견고한 재질로 인해 다양한 용도로 활용됩니다. 특히, 발포우레탄폼은 부식이나 노후 등에도 강한 내구성을 가지고 있어 건축 및 인테리어에서 효율적으로 활용됩니다.
# - pattern = r'[^a-zA-Z가-힣\d.,?!\s()-~"\'·:%&#*℃㎥°+×÷‘’]' 이걸로 3개 제외 모두 커버할 수 있음
#     - 깨진 글자가 존재하지는 않으나 ℃ <-> °C 처럼 같은 의미인데 다르게 표현되는 경우도 있음.
#     - 질문에서는 특수문자가 ().,?!- 말고는 존재하지 않음. -> 테스트 데이터에서도 그냥 없애버리는 것도 방법일듯.

# %%
train[['답변_1', '답변_2', '답변_3', '답변_4', '답변_5']].head(3)
# Out:
#                                                          답변_1  \
# 0      면진장치란 지반에서 오는 진동 에너지를 흡수하여 건물에 주는 진동을 줄여주는 진동 격리장치입니다.
# 1                          내진 설계의 종류로 내진구조, 제진구조, 면진구조가 있습니다.
# 2  철골구조는 건물의 외벽에는 그다지 하중이 걸리지 않기 때문에 고층 건물의 건축이 가능한 것이 장점입니다.
#
#                                                                                                                                                       답변_2  \
# 0                                                     면진장치란 건물의 지반에서 발생하는 진동 에너지를 흡수하여 건물을 보호하고, 진동을 줄여주는 장치입니다. 주로 지진이나 기타 지반의 진동으로 인한 피해를 방지하기 위해 사용됩니다.
# 1  내진설계에는 내진구조, 제진구조, 면진구조가 있습니다. 내진구조는 건물 구조물이 지진의 힘에 따라 변형되는 것을 방지하기 위해 설계됩니다. 제진구조는 건물의 지반을 고정시키거나 지진의 힘을 줄이기 위해 설계되며, 면진구조는 건물을 지진에 노출되는 방향으로부터 보호합니다.
# 2  철골구조의 장점은 건물의 외벽에는 그다지 하중이 걸리지 않기 때문에 고층 건물의 건축이 가능하다는 것입니다. 또한, 철골구조는 화재, 지진 및 기타 자연재해로부터 건물을 보호하는 안전성이 뛰어나며, 건물 내부 공간을 유연하게 구성할 수 있는 유연성 역시 갖추고 있습니다.
#
#                                                                                                                                                                                                                                                                                              답변_3  \
# 0                                                                                                                                          면진장치란 지반으로부터 발생하는 진동 에너지를 흡수하여 건물에 전달되는 진동을 줄여주는 장치를 말합니다. 이를 통해 건물의 안전성과 안정성을 향상시키고, 지진 등의 외부 충격으로부터 보호하는 역할을 합니다. 지진으로 인한 건물의 피해를 최소화하기 위해 주로 사용됩니다.
# 1  내진설계에는 주로 내진구조, 제진구조, 면진구조의 세 가지 종류가 있습니다. 이들은 지진으로부터 건물을 보호하기 위한 다양한 방법을 제공합니다. 내진구조는 기존 구조물에 보강을 가하는 방식으로 지진으로부터의 영향을 최소화하는 방법을 사용하며, 제진구조는 건물의 터널 또는 이동 조인트를 통해 지진의 영향을 줄이는 방법을 사용합니다. 마지막으로 면진구조는 건물의 외벽에 대각선 형태의 보강을 사용하여 지진으로부터의 영향을 줄입니다. 이러한 다양한 내진설계의 종류를 통해 안전한 건물을 설계하고 건축할 수 있습니다.
# 2                                                                                                          철골구조의 장점은 건물의 외벽에 하중이 적게 걸리기 때문에 고층 건물의 건축이 용이하다는 점입니다. 또한 철골은 높은 강도를 가지고 있어 안정성이 뛰어나며, 시공성이 우수하여 건설 기간을 단축할 수 있는 장점이 있습니다. 또한 철골은 재사용이 가능하고, 화재에 강한 성질을 가지고 있어 안전성이 높다는 점도 장점으로 꼽힙니다.
#
#                                                                                                                                                                                                                                                       답변_4  \
# 0                                                                                                                                              면진장치는 건물의 지반으로부터 오는 진동 에너지를 흡수하여 건물에 전달되는 진동을 최소화해 주는 진동 격리장치입니다. 이를 통해 건물 내부의 진동을 줄이고 안정성을 유지하는 데 도움을 줍니다.
# 1  내진설계에는 주로 내진구조, 제진구조, 면진구조가 사용됩니다. 내진구조는 건물 구조물 전체에 지진으로부터의 영향을 분산시키기 위해 설계되었습니다. 반면, 제진구조는 지진으로 인한 충격을 줄이기 위해 주로 건물의 지지대에 설치됩니다. 또한 면진구조는 건물의 외벽에서 지진으로부터 보호받기 위한 설계 방식입니다. 이러한 내진설계의 종류는 지역의 지진 환경 및 건물의 특성에 맞게 선택되며, 안전하고 견고한 건물을 만드는 데 중요한 역할을 합니다.
# 2                                                                                                                                           철골구조의 장점은 건물의 외벽이 하중이 걸리지 않아 공간 활용이 용이하고, 고층 건물을 건설할 수 있다는 것입니다. 또한 철골구조는 강하고 안정적이며, 화재에 대한 내성이 있는 것으로도 소개됩니다.
#
#                                                                                                                                                                                                                                                              답변_5
# 0                                                                                                                                                               면진장치는 건물에 오는 지반 진동의 영향을 최대한으로 흡수하여 건물에 전달되는 진동을 줄여주는 장치입니다. 지반으로부터 오는 진동 에너지의 영향을 완화시키기 위해 사용됩니다.
# 1  내진 설계에는 다양한 종류가 있지만, 대표적으로 내진구조, 제진구조, 면진구조가 있습니다. 내진구조는 건물이 지진으로부터 받는 영향을 줄여주는 설계로, 건물 내부에 설치된 강화 기구를 이용해 지진 시 건물의 안전을 보장합니다. 제진구조는 지진이 발생했을 때 건물의 토대를 보호하기 위한 설계로, 건물의 기초 부분에 특수한 기술을 적용하여 지진의 영향을 최소화합니다. 마지막으로 면진구조는 건물의 외벽을 특수한 방법으로 보강하여 지진에 대비하는 설계입니다.
# 2                                  철골구조의 장점은 건물의 외벽에 하중이 크게 걸리지 않아 고층 건물을 건축할 수 있는 점입니다. 또한 철골은 높은 강도를 가지고 있어 건물 전체에 안정성을 부여하며, 공간을 유연하게 활용할 수 있는 장점도 있습니다. 또한 철골구조는 건축 시간을 단축시키고, 건물의 변형을 예방하는 데에도 도움이 됩니다. 그러므로 고층 건물뿐만 아니라 다양한 형태의 건물을 건축하는 데 유용하게 활용될 수 있습니다.

# %%
print(train['답변_1'].apply(len).mean())
print(train['답변_2'].apply(len).mean())
print(train['답변_3'].apply(len).mean())
print(train['답변_4'].apply(len).mean())
print(train['답변_5'].apply(len).mean())
# Out:
# 95.73136645962732
# 194.50465838509317
# 194.60714285714286
# 196.9673913043478
# 195.38509316770185

# %%
pattern = r'[^a-zA-Z가-힣\d.,?!\s()-~"\'·:%&#*℃㎥°+×÷‘’]'
# ℃ 2개
# ㎥ 1개
# ㅕ 1개
# ° 1개
# × ÷ 1개
# ‘’ 1개
# 
mask = train[['답변_1', '답변_2', '답변_3', '답변_4', '답변_5']].apply(lambda x: x.str.contains(pattern)).any(axis=1)
print(len(train[mask]))
train[mask]
# Out:
# 3
#             id                   질문_1  \
# 195  TRAIN_195        노출콘크리트의 장점이 뭐야?
# 628  TRAIN_628       결로 판정 기준이 어떻게 돼?
# 629  TRAIN_629  발코니에 결로가 발생하는 원인은 뭐야?
#
#                                               질문_2 category  \
# 195                             노출콘크리트의 단점은 무엇인가요?      마감재
# 628  결로가 발생하는 기준은 무엇이며, 어떤 조건에서 결로로 인정되는지 알고 계신가요?   타 마감하자
# 629                    발코니에 결로가 발생하는 주된 이유는 무엇인가요?   타 마감하자
#
#                                                                                               답변_1  \
# 195                    노출콘크리트는 모던하며 다양한 인테리어 효ㅕ과와 공간의 확장감을 주고 별도의 마감재가 필요없으며 표면의 강도가 높다는 장점이 있습니다.
# 628  결로 판정 기준은 국토교통부 설계기준으로 실내온도 25도, 상대습도 50%, 외부온도 -15도에서 결로가 발생하지 않는 온도저하율 값인 0.28을 기준으로 판정합니다.
# 629   발코니에 결로가 발생하는 원인은 발코니에 단열 및 방습조치가 되지 않은 상태에서 실내의 습기가 실외로 이동하다 온도가 낮은 외벽이나 샤시를 만나면 결로가 발생합니다.
#
#                                                                                                                                                                                                답변_2  \
# 195  노출콘크리트의 장점은 모던하며 공간의 확장감을 주고, 별도의 마감재가 필요하지 않으며 표면의 강도가 높다는 점입니다. 이는 시공 및 유지보수 비용을 줄여주고 내구성이 강한 인테리어 소재로 활용할 수 있다는 것을 의미합니다. 노출콘크리트는 트렌디한 외관과 함께 강력한 구조적 특성을 제공하여 건물의 안정성을 높이는 데 도움을 줄 수 있습니다.
# 628                                      결로 판정 기준은 주로 국토교통부의 설계기준을 따릅니다. 이에 따라, 국토교통부의 기준에 따르면, 실내 온도가 25도, 상대습도가 50%이고 외부온도가 -15도일 때 결로가 발생하지 않는 온도저하율 값이 0.28 이상이어야 합니다. 이를 기준으로 결로 현상을 판정하게 됩니다.
# 629                             발코니에 결로가 발생하는 가장 일반적인 원인은 발코니에 충분한 단열 및 방습조치를 하지 않은 상태에서, 실내의 습기가 발코니로 이동하여 온도가 낮은 외벽이나 창문 프레임과 만나면 발생합니다. 이러한 조건은 결로가 형성되기에 이상적인 환경을 제공하므로, 적절한 방습 및 단열 처리가 필요합니다.
#
#                                                                                                                                                                                                                                                    답변_3  \
# 195                                                                                                                                 노출콘크리트의 장점은 모던한 느낌과 공간 확장감, 특별한 마감재 없이도 사용할 수 있으며 표면의 강도가 높아 내구성이 좋다는 점입니다. 또한 다양한 인테리어 효과를 연출할 수 있다는 점도 장점으로 꼽힙니다.
# 628  결로 판정 기준은 국토교통부의 설계기준에 따라 결로가 발생하지 않는 조건을 설정하고 있습니다. 보통 이 기준은 실내온도 25도, 상대습도 50%, 외부온도 -15도에서 결로가 발생하지 않는 온도저하율 값이 0.28 이하일 때 해당 시공물은 결로가 발생하지 않는 것으로 판정됩니다. 이 기준은 건축물 내부의 온‧습도 및 외부 온도를 바탕으로 건축물이나 시공물에 발생할 수 있는 결로 현상을 사전에 예방하기 위한 목적으로 설정되었습니다.
# 629                                          발코니에 결로가 발생하는 원인은 외부와 내부의 온‧습도차 때문입니다. 발코니에서 습기가 외벽이나 창틀과 만나면 그 부분이 축축해지고, 여기에 습기가 응축하여 결로가 생기게 됩니다. 이 때, 발코니에 단열 및 방습조치가 제대로 이루어지지 않으면 결로가 더욱 쉽게 발생하게 됩니다. 따라서 발코니에 대한 단열 및 방습 장치를 설치하여 습기 유발을 최소화해야 합니다.
#
#                                                                                                                                                                                            답변_4  \
# 195                                  노출콘크리트의 장점은 먼저, 모던하고 다양한 인테리어 효과와 공간의 확장감을 주어 시공 비용을 절감할 수 있다는 점입니다. 또한, 노출콘크리트는 별도의 마감재가 필요하지 않아 시공 및 유지 보수 비용을 줄일 수 있으며, 표면의 강도가 높아 내구성이 뛰어나다는 장점이 있습니다.
# 628  결로 판정 기준은 국토교통부의 설계기준에 따라 결정됩니다. 일반적으로, 실내온도 25도, 상대습도 50%, 외부온도 -15도에서 결로가 발생하지 않는 온도저하율 값인 0.28을 기준으로 판정합니다. 즉, 이 기준을 토대로 건축물의 내부 및 외부 온도, 상대습도 등의 요소를 종합적으로 고려하여 결로가 발생할 가능성을 판단하게 됩니다.
# 629  발코니에 결로가 발생하는 주된 원인은 발코니에 단열 및 방습 처리가 충분히 이루어지지 않은 상태에서, 실내의 습기가 발코니로 이동하여 온도가 낮은 외벽이나 창틀에 의해 만나면 결로가 형성된다는 점입니다. 이러한 상황에서는 단열 및 방습재의 부족, 외피 재료의 특성, 외부 온도 등이 결로 형성을 촉진하는 요인으로 작용할 수 있습니다.
#
#                                                                                                                                                                                        답변_5
# 195                        노출콘크리트의 장점으로는 모던한 느낌과 함께 다양한 인테리어 효과와 공간의 확장감을 줄 뿐만 아니라, 별도의 마감재가 필요 없으며 표면의 강도가 높다는 점이 있습니다. 이로써 내구성이 뛰어나고 유지보수가 간편하며 친환경적인 재료로 인테리어나 공간 디자인에서 꾸준히 인기를 끌고 있습니다.
# 628  결로 판정 기준은 국토교통부의 설계기준에 따라서 결정됩니다. 일반적으로 실내온도 25도, 상대습도 50%, 외부온도 -15도에서 결로가 발생하지 않는 온도저하율 값인 0.28을 기준으로 판정합니다. 이 기준은 건물 내부의 온도와 습도, 외부 온도 등을 고려하여 건축물이 안전하고 건강한 환경을 제공할 수 있도록 설정되었습니다.
# 629                                발코니에 결로가 발생하는 원인은 주로 발코니에 충분한 단열 및 방습 처리가 이루어지지 않은 상태에서, 실내 습기가 발코니로 이동하여 온도가 낮은 외벽이나 샤시에 충돌함으로써 발생합니다. 따라서 충분한 방습 및 단열 처리가 필요하며, 적절한 환기 및 습도 관리가 필요합니다.
